# %% [markdown]
# # __`K Nearest Neighbor Regressor`__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt 
import seaborn as sns

# %%
from sklearn.datasets import make_regression    
X, y = make_regression(n_samples = 1000, n_features = 2, noise = 10, random_state = 42)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

X_train.shape, X_test.shape
# Out:
# ((670, 2), (330, 2))

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor()
regressor.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 41.76673258,  -7.59437128, -16.65330434, -12.40227133,
#         36.50390441,  20.2429261 ,  61.33943992, -29.17202648,
#        -71.76709886, -11.9092177 ,  16.33441338,  -3.05077276,
#        -67.94559513,  59.90553659,  15.71045932,   0.1568295 ,
#        -60.10947793,  25.4844424 , -28.8095753 ,  27.02911181,
#         20.8555342 ,  15.65608547, -23.61510645, -41.03200396,
#        -43.92434524,  25.77610628, -58.95652775,  61.61204386,
#        -22.26969946,  73.57828341, -77.28105454,  33.68023612,
#        -59.88441434,  -7.59437128, -52.41802667,  -6.1272399 ,
#         20.57984555,  32.86381788,  14.41379048, -46.12209025,
#         84.06465502,  28.9556839 ,  40.33491469, -70.67778804,
#         21.6520122 ,  23.45246046, -30.06738109,  -7.56893351,
#         60.3765076 ,  66.69890142,  61.10758863,  77.06956965,
#        -57.91445319, -32.73737476, -46.12209025, -24.65667254,
#        -33.56726916,  34.05975968,  89.90091082,  29.61443663,
#         37.95277128,   5.04859495, -23.51901164,  -4.11565876,
#         -7.80691962, -16.65330434,   3.49171402,  21.67231896,
#        -12.90919449, -57.26160031,  40.66972968,  78.00157096,
#         61.11775102,   1.47567069,  63.89953105, -33.5922652 ,
#        -13.76035408, -39.44840122, -16.56328349, -48.92333782,
#        -15.61948484,  45.90272354,   8.40525078,  36.73752101,
#         41.40175657,   6.47332971,  13.07202496,   7.58314716,
#         35.44250449,  40.03343209, -41.40557396,  19.97214713,
#         14.89845096,  19.68972529,   8.94950866, -64.35781865,
#        -12.19908632,  16.00016068,  -2.47663538,   1.42206867,
#         57.88776215,  61.33943992,   6.50605749, -49.08062952,
#         -6.6080568 , -38.608091  , -19.45416387,   6.6450752 ,
#         21.93066881,   2.18181382,  27.85931962,  -1.85926256,
#        -43.92434524, -17.30127654,  17.13133785,  61.15460221,
#        -11.52400304,  -4.92050437,  24.43431304,   5.32818473,
#         33.80058915,  39.15275408,  13.03089338,  -4.02827475,
#        -55.32371465,  13.80896814,  37.25598446, -41.03200396,
#        -30.42100017,  29.61443663, -44.00108896,   6.82585827,
#         -3.17787417, -36.58968371,  -7.03440934,  16.20729958,
#         22.95114492,  12.15578949, -36.62503066, -15.24968274,
#         -6.49041581, -16.0242914 , -22.14999233, -18.22553452,
#          8.07032818,  41.16643614,  20.51852576, -22.95474019,
#        -40.49117341, -43.794263  ,  76.62059357,  30.05986267,
#        -51.44700654, -22.76858846, -12.83562601, -37.32703913,
#         11.77846459,  32.86381788,  16.20729958,  72.41127065,
#         -2.81278992,  87.77924768, -21.48631572,  -2.3868837 ,
#        -72.11199726, -43.04299014,  75.59563254, -26.27827351,
#         11.33531029,  71.72699605,  51.86425569, -71.65860129,
#         52.40693882,  66.62641657,  31.32616391, -31.31316097,
#        -35.73853545, -49.9394638 , -10.49813206,   4.17805419,
#         -7.56893351,  88.2403063 ,  21.1505767 , -36.58968371,
#         84.37511448,  25.4844424 ,   4.17805419, -30.37387835,
#         25.09839355, -20.57872769, -13.38346682,  -8.8591952 ,
#        -14.96227082,   0.60476164,  37.79294369, -64.76162549,
#          2.74285668, -72.35586733,  -5.76098143,   7.00237789,
#         -5.80739236,  36.76116956,  36.37517621, -53.39549678,
#         -7.10930777,   4.4011135 ,   8.57776364, -19.08924607,
#         27.85931962, -46.20644088,   2.83081414, -50.49343667,
#        -46.52513567,  24.19512292, -21.73497763,   8.8553438 ,
#         19.20731738,  14.58881778,  23.84077623, -17.08972948,
#         16.70099925,  39.52579144,   1.92764447,  16.72852634,
#        -58.85355681,  16.34663634, -18.99922516, -26.02740049,
#         14.09579828,  32.45182884, -43.37841152,  -3.60927612,
#         38.76952853,  -3.16569162,  29.8018037 ,  -8.48259428,
#         76.535979  , -35.14150416,  36.97176667, -36.58968371,
#         17.13133785, -38.79359743, -13.08594737, -58.85355681,
#          9.10387588,  41.16643614, -18.22553452,  35.25519986,
#         70.64004792,  23.45246046,  63.59781401,  75.59563254,
#         74.04400473,  58.14391677,   0.89893394, -77.73898476,
#         -2.47663538,  -3.05077276, -18.64020272, -42.21190296,
#        -26.40993884,  76.11660731,  58.42636408,  43.9489958 ,
#         -1.51587329,  23.03453608,  12.67728226,  73.69306157,
#         -1.63844744,  12.48644707,  -5.88597445, -56.52441877,
#        -11.05914609,   9.56619541, -31.45031773, -52.52998431,
#        -47.90930077, -49.37481635, -10.94637879,  19.17418885,
#         13.77910054,  -3.99946297,   4.46835086, -58.30010508,
#         11.74943839, -30.89301683,   7.09850839,  -3.9042723 ,
#         30.49030121, -32.5971955 , -57.73327337,  44.23294318,
#         -7.71825546, -49.37481635, -33.44890008,  -3.28613297,
#        -16.0242914 ,  85.42598965, -65.17976683,  59.09224762,
#        -26.65897685, -10.41949376,  45.18686348, -23.7609698 ,
#         69.17783828, -10.87847519,  46.772698  ,  24.00328486,
#         34.72090419,  13.50394296,  16.70099925,  14.67930846,
#         19.68972529,   1.21786175,   1.16934366,  10.59492105,
#         10.09219333,   8.44250419,  44.18087623, -20.36607934,
#         15.71045932,   8.2185716 , -26.43082201,  36.76116956,
#         44.94488021, -25.56456033,  -1.71871581, -45.84985281,
#          1.16934366, -66.13534614])

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.9155927746462499
# 9.269174435861803
# 132.70133826064995

# %% [markdown]
# ## __`HyperParameter Tuning`__

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

neighbors = [7, 8, 9, 10, 11, 12, 13]
w = ['uniform', 'distance']
algo = ['kd_tree', 'ball_tree', 'brute']
p = [1, 2, 3, 4, 5]
l_s = [1, 2, 5]   # Data is small so wo predictin ko fast krna chaa rha hai

cv = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 42)

params = dict(n_neighbors = neighbors, algorithm = algo, p = p, leaf_size = l_s, weights = w)
params
# Out:
# {'n_neighbors': [7, 8, 9, 10, 11, 12, 13],
#  'algorithm': ['kd_tree', 'ball_tree', 'brute'],
#  'p': [1, 2, 3, 4, 5],
#  'leaf_size': [1, 2, 5],
#  'weights': ['uniform', 'distance']}

# %%
grid = GridSearchCV(estimator = KNeighborsRegressor(), param_grid = params, verbose = 3, n_jobs = -1, scoring = 'r2', cv = 15)
grid.fit(X_train, y_train)
# Out:
# Fitting 15 folds for each of 630 candidates, totalling 9450 fits
# GridSearchCV(cv=15, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'algorithm': ['kd_tree', 'ball_tree', 'brute'],
#                          'leaf_size': [1, 2, 5],
#                          'n_neighbors': [7, 8, 9, 10, 11, 12, 13],
#                          'p': [1, 2, 3, 4, 5],
#                          'weights': ['uniform', 'distance']},
#              scoring='r2', verbose=3)

# %%
grid.best_params_
# Out:
# {'algorithm': 'kd_tree',
#  'leaf_size': 1,
#  'n_neighbors': 10,
#  'p': 1,
#  'weights': 'distance'}

# %%
y_pred = grid.predict(X_test)
y_pred
# Out:
# array([ 38.05562859,  -3.2130404 , -16.23171922, -11.53418981,
#         37.63249024,  18.65092356,  61.08082983, -32.17403182,
#        -73.99794017, -13.11721621,  23.91599377, -14.40944525,
#        -69.12769103,  56.20846239,  15.70917683,   1.72548302,
#        -54.77900882,  24.47523064, -25.34665616,  22.95975194,
#         24.65389454,  16.49988779, -21.51371669, -39.07317052,
#        -45.79148958,  27.98664106, -56.39633447,  58.24926217,
#        -20.34458175,  73.70558987, -71.60170961,  27.98079483,
#        -63.66882222,  -6.66990945, -49.83557522,  -5.18499476,
#         21.98079988,  35.26251743,  12.54270821, -46.01529816,
#         83.93026501,  28.23607222,  41.60563897, -78.93766626,
#         19.91281181,  27.9965233 , -36.8379866 ,  -9.50060421,
#         60.83609202,  70.18293842,  59.80517045,  74.31079812,
#        -64.64709854, -32.90394553, -45.95336978, -23.03568347,
#        -32.51088446,  38.01487718,  88.65047045,  32.24965809,
#         35.10384441,   5.28310377, -24.52116973,  -2.75542025,
#         -4.48431802, -18.1627698 ,   6.85617399,  23.14282011,
#        -10.57270324, -56.0150152 ,  37.73727332,  68.54712352,
#         59.57422643,   3.89152017,  62.39886464, -31.23488087,
#        -13.70722158, -38.59417194, -14.84451899, -44.25195631,
#        -14.38188745,  43.79826525,   6.06638773,  33.48334243,
#         34.73459157,  10.41964192,  17.53480601,  12.57338712,
#         34.76382318,  37.83638167, -41.2371507 ,  14.90859286,
#         13.38272473,  13.56702783,   5.70762404, -60.97468547,
#        -17.66584836,  19.30074153,  -3.19720313,   3.90097686,
#         59.82894145,  61.75400826,   9.26353826, -45.35744552,
#         -5.47928534, -30.38870398, -18.29238578,   2.61562006,
#         17.52372335,  -0.48901355,  25.39700526,  -5.81951609,
#        -37.44893469, -15.21600788,  20.01624926,  61.32551887,
#        -11.9996013 , -10.81832721,  23.28652383,   7.17044318,
#         30.08419361,  38.06666187,   4.24176359, -13.16929954,
#        -51.92366843,  17.79178262,  39.6102527 , -39.32597984,
#        -30.72198844,  31.99487983, -46.35879114,  11.79625973,
#         -6.10406177, -35.28095223, -13.92783365,  13.15250997,
#         25.70586979,  13.13392435, -36.11777186, -15.41679012,
#         -5.8721733 , -14.81884159, -17.92609397, -18.69421776,
#          7.55031553,  36.30547312,  19.81204693, -18.31177608,
#        -39.02962494, -35.8171483 ,  66.44990532,  24.95166983,
#        -46.87606787, -20.45237919, -17.38380074, -39.69423176,
#         14.81715472,  34.71560496,  14.34378736,  67.73008079,
#          1.92175977,  78.01950593, -17.58995415,  -1.67973574,
#        -71.695924  , -43.41114493,  78.28615491, -27.18039867,
#         21.47379459,  72.0625413 ,  52.33426738, -71.2938633 ,
#         47.27690565,  65.28030949,  29.89626556, -30.38786546,
#        -30.55114612, -41.66902977,  -8.04893239,   8.29790845,
#         -5.59594741,  78.20550684,  21.17016073, -37.90723682,
#         88.51112599,  26.0058531 ,   7.48166512, -31.22920832,
#         30.67029451, -17.34589403, -12.45921647,  -5.12717309,
#        -17.27370748,  -1.21386908,  39.14142839, -63.83148613,
#          6.10978538, -74.51806994,  -1.89264187,   6.5323434 ,
#         -3.76801842,  37.26056337,  32.47436117, -54.0093238 ,
#         -5.21934412,   6.21252785,   6.29617916, -17.16760873,
#         31.1298395 , -42.3587289 ,   4.48242702, -46.52519586,
#        -45.6074015 ,  21.5434031 , -18.28022193,   9.97137772,
#         17.89309337,  13.61577401,  24.76773853, -16.07898768,
#         19.75266707,  45.21247709,   6.03399837,  18.63881589,
#        -58.62357381,  12.3460131 , -15.90395368, -22.57552183,
#         13.36941824,  26.93106299, -41.51948649,  -4.73643693,
#         41.44344941,  -6.88381349,  25.88335636,  -6.65953124,
#         70.64163131, -43.21375648,  37.17971704, -32.53298332,
#         20.77973422, -36.52772278, -12.9109712 , -54.21131499,
#          6.47131911,  40.2209147 , -17.67411403,  32.07290373,
#         70.47482207,  28.04640234,  61.52437627,  74.92776265,
#         78.30747737,  55.41750562,   2.95797681, -70.07516511,
#         -3.42057373,  -4.07469827, -20.32662712, -39.70533337,
#        -26.48439587,  77.45967311,  52.84255965,  41.87292678,
#         -3.61368717,  25.80055932,  17.01365326,  76.66856174,
#         -3.50895558,  16.60670966,  -6.06818014, -58.43940717,
#        -16.3832743 ,   9.17540595, -34.18504404, -55.70561791,
#        -50.99050521, -45.49552152,  -8.13796921,  15.39044065,
#         14.09912244,   0.9726989 ,   4.24844878, -58.81562687,
#         14.07850164, -26.26487384,  -1.19096372,  -8.54728309,
#         32.52279597, -37.38445817, -54.8542938 ,  39.53621942,
#         -8.34080412, -44.58197799, -33.83925297,  -1.45222156,
#        -14.49897209,  77.5466165 , -60.25788145,  63.36421473,
#        -26.63781742, -14.93248532,  41.52687819, -22.95230599,
#         72.46616775,  -9.64544794,  47.84344742,  22.73482454,
#         33.05733792,  11.85465607,  18.78827843,  14.93819693,
#         13.94661545,   7.05302405,  -2.4367477 ,  13.75450632,
#         10.0764148 ,  -2.95194944,  45.98244028, -21.8309718 ,
#         15.79198816,   6.2863123 , -20.0691999 ,  40.83737042,
#         42.21674529, -20.51198844,  -1.26084137, -51.36715761,
#         -2.12870487, -73.95758003])

# %%
print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 0.9212319135982416
# 123.83573128884318
# 8.855239214233727
